# %% [markdown]
# ### 這個notebook產生資料的規則為
# 若 mass/volume > 0.5 and length >170 則會發光(正樣本)
# 其餘為負樣本(不發光)

# %%
import numpy as np
import pandas as pd

# Modelling Algorithms
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier , GradientBoostingClassifier

# Modelling Helpers
from sklearn.preprocessing import Imputer , Normalizer , scale
from sklearn.cross_validation import train_test_split , StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.linear_model  import LogisticRegression

# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
import warnings
from IPython.display import Image 
warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from data import get_Xy,read_dataset,generate_dataset
# Out:
# D:\anaconda\envs\dl\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def plot_hist(title,series,color,edge_min,edge_max,intv,ax):
    bins = (edge_max-edge_min)//intv
    ax.grid(zorder=0)
    if color is not None:
        ax.hist(series, bins=bins,color=color,range=(edge_min,edge_max),zorder=1)
    else:
        ax.hist(series, bins=bins,range=(edge_min,edge_max),zorder=1)
    ax.set_title(title)
def filename_mapping(rule_name,dataset_name,pos_num,neg_num):
    return '%s/%s_%d_%d.csv'%(rule_name,dataset_name,pos_num,neg_num)
def generate_datasets(train_num_tls,test_num_tls):
    rules = ['rule3']
    for rule_name in rules:
        for pos_num,neg_num in train_num_tls:
            filename = filename_mapping(rule_name,'train',pos_num,neg_num)
            generate_dataset(pos_num,neg_num,rule_name,filename)
        for pos_num,neg_num in test_num_tls:
            filename = filename_mapping(rule_name,'test',pos_num,neg_num)
            generate_dataset(pos_num,neg_num,rule_name,filename)
def read_datasets(rule_name,dataset_name,pos_neg_list):
    df_list = []
    for pos_num,neg_num in pos_neg_list:
        path = filename_mapping(RULE_NAME,dataset_name,pos_num,neg_num)
        df_list.append(read_dataset(path))
    return df_list
def visualize_tree(clf,feature_names=["volume","mass","length","shape","color","rough"]):
    from sklearn.externals.six import StringIO  
    import pydotplus 
    from sklearn import tree
    dot_data = tree.export_graphviz(clf, out_file= None, 
                         feature_names=feature_names,  
                         class_names=["dark","light"],  
                         filled=True, rounded=True)  
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
generate_datasets([(100,30),(100,100)],[(100,30),(100,100)])

# %% [markdown]
# ## 讀取多筆資料集並且顯示
# 有兩筆訓練資料集和兩筆測試資料集
# 訓練資料集:一筆為正樣本(會發光) 100筆 負樣本(不會發光) 100筆
# 另一筆為正樣本100筆 負樣本30筆
# 測試資料集:一筆為正樣本(會發光) 100筆 負樣本(不會發光) 100筆
# 另一筆為正樣本100筆 負樣本30筆
#
# 在一筆資料集訓練玩模型後,會分別在兩筆測試資料集測試。
# 觀察當訓練樣本不平均時(或平均時),在測試資料集正負樣本平均(或不平均的表現)

# %%
RULE_NAME = 'rule3'
train_df_list = read_datasets(RULE_NAME,'train',[(100,100),(100,30)])
test_df_list =  read_datasets(RULE_NAME,'test',[(100,100),(100,30)])

# %%
for df in train_df_list:
    display(df.head())
for df in train_df_list:
    display(df.describe())
for df in train_df_list:
    display(df.info())
# Out:
#    volume  mass  length  shape  color  rough  light
# 0     185   115     191      1      3      0      1
# 1     113   106     199      1      0      0      1
# 2     193    98     199      2      3      1      1
# 3     328   174     180      2      1      1      1
# 4     202   169     197      0      0      1      1
#    volume  mass  length  shape  color  rough  light
# 0     276   157     189      2      2      0      1
# 1     227   146     178      2      0      1      1
# 2     129   172     177      2      3      0      1
# 3     284   159     190      2      2      0      1
# 4     363   193     192      1      0      1      1
#            volume        mass      length       shape       color       rough  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   261.615000  132.990000  179.525000    0.965000    1.435000    0.480000
# std    114.111718   45.127624   14.569169    0.765969    1.145573    0.500854
# min    103.000000   52.000000  150.000000    0.000000    0.000000    0.000000
# 25%    156.000000   93.000000  170.000000    0.000000    0.000000    0.000000
# 50%    258.500000  141.500000  182.000000    1.000000    1.000000    0.000000
# 75%    347.500000  174.000000  192.000000    2.000000    2.000000    1.000000
# max    499.000000  200.000000  200.000000    2.000000    3.000000    1.000000
#
#             light
# count  200.000000
# mean     0.500000
# std      0.501255
# min      0.000000
# 25%      0.000000
# 50%      0.500000
# 75%      1.000000
# max      1.000000
#            volume        mass      length       shape       color       rough  \
# count  130.000000  130.000000  130.000000  130.000000  130.000000  130.000000
# mean   236.607692  141.853846  183.253846    1.169231    1.530769    0.461538
# std     95.139106   40.556614   11.223806    0.845769    1.169300    0.500447
# min    102.000000   52.000000  150.000000    0.000000    0.000000    0.000000
# 25%    163.500000  110.500000  175.250000    0.000000    0.000000    0.000000
# 50%    223.500000  150.500000  186.000000    1.000000    2.000000    0.000000
# 75%    286.250000  173.750000  192.000000    2.000000    3.000000    1.000000
# max    484.000000  200.000000  200.000000    2.000000    3.000000    1.000000
#
#             light
# count  130.000000
# mean     0.769231
# std      0.422955
# min      0.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
# volume    200 non-null int64
# mass      200 non-null int64
# length    200 non-null int64
# shape     200 non-null int64
# color     200 non-null int64
# rough     200 non-null int64
# light     200 non-null int64
# dtypes: int64(7)
# memory usage: 11.0 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 7 columns):
# volume    130 non-null int64
# mass      130 non-null int64
# length    130 non-null int64
# shape     130 non-null int64
# color     130 non-null int64
# rough     130 non-null int64
# light     130 non-null int64
# dtypes: int64(7)
# memory usage: 7.2 KB
# None

# %% [markdown]
# # EDA
#
# ### target variable : light
# 以下的圖中
# dataset1代表: 100個正樣本100個負樣本組成的訓練資料集
# dataset2代表: 100個正樣本30個負樣本組成的訓練資料集
# light代表正樣本
# dark代表負樣本

# %%
def plot_target_variable(df_list):
    num_df = len(df_list)
    fig, axs  = plt.subplots(num_df, 2,figsize=(10,5))
    for i,df in enumerate(df_list):
        df['light'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,ax=axs[i][0])
        sns.countplot(x='light',data=df,ax=axs[i][1])
        axs[i][0].set_title('dataset %d'%(i+1))
        axs[i][1].set_title('dataset %d'%(i+1))
    plt.tight_layout()
plot_target_variable(train_df_list)

# %%
def plot_value_feature(df_list,titles,colors,min_val,max_val,intv,y_ticks,y_lim):
    num_df = len(df_list)
    fig, axs  = plt.subplots(1,num_df,figsize=(10,5))
    for i,df in enumerate(df_list):
        ax = axs[i]
        if y_ticks is not None:
            ax.set_yticks(y_ticks)
        if y_lim is not None:
            ax.set_ylim(y_lim)   
        plot_hist(titles[i],df,colors[i],min_val,max_val,intv,ax)
    plt.tight_layout()

# %% [markdown]
# ### volume
# 以下的圖表為volume的histogram
# 觀察:
# - 由於dataset2正樣本的數量為負樣本的三倍以上
# 而volume愈大愈有機會成為負樣本,所以大部分的資料volume都在300以下
# 而dataset1 300以上和以下的數量就差不多
# - dark(負樣本)的資料中,volume>300的占多數;light(正樣本)的資料中,volume<300的占多數
# - 由於mass的最大值為200,而mass/volume>0.5才有可能是正樣本,所以volume>400的正樣本不存在

# %%
plot_value_feature([df['volume'] for df in train_df_list],['volume of dataset1','volume of dataset2'],['r','g'],100,500,50,np.arange(0,50,5),(0,50))
for i,df in enumerate(train_df_list):
    plot_value_feature([df['volume'][df['light']==label] for label in (0,1)],['dataset %d: volume of dark'%(i+1),'dataset %d :volume of light'%(i+1)],['r','g'],100,500,50,np.arange(0,50,5),(0,50))

# %% [markdown]
# ### mass
# 以下的圖表為mass的histogram
# 觀察:
# - dataset1 並無明顯偏向哪一邊的趨勢,dataset2由於正樣本佔多數,靠近兩百的資料比較多
# - light(正樣本)的資料中,mass<120的占多數;負樣本並沒有像正樣本那樣有明顯偏向哪一邊的趨勢

# %%
plot_value_feature([df['mass'] for df in train_df_list],['mass of dataset1','mass of dataset2'],['r','g'],50,200,10,\
                    np.arange(0,40,5),(0,40))
for i,df in enumerate(train_df_list):
    plot_value_feature([df['mass'][df['light']==label] for label in (0,1)],['dataset %d: mass of dark'%(i+1),'dataset %d: mass of light'%(i+1)],\
                           ['r','g'],50,200,10,np.arange(0,40,5),(0,40))

# %% [markdown]
# ### length
# 以下的圖表為length的histogram
# 觀察:
# - dataset2大部分的長度資料都比較靠近兩百
# - light(正樣本)的資料中由於規則的原因,沒有 <170的正樣本;負樣本並沒有像正樣本那樣有明顯偏向哪一邊的趨勢

# %%
plot_value_feature([df['length'] for df in train_df_list],['length of dataset1','length of dataset2'],['r','g'],150,200,10,\
                    np.arange(0,70,5),(0,70))
for i,df in enumerate(train_df_list):
    plot_value_feature([df['length'][df['light']==label] for label in (0,1)],['dataset %d: length of dark'%(i+1),'dataset %d: length of light'%(i+1)],\
                           ['r','g'],150,200,10,np.arange(0,70,5),(0,70))

# %% [markdown]
# # Model

# %%
from data import evaluate
import graphviz

# %% [markdown]
# ## Decision tree
# 第一張圖為用100筆正樣本和100筆負樣本訓練產生的決策樹
# 第二張圖為用100筆正樣本和30筆負樣本訓練產生的決策樹
#
# 第一個Decision tree的feature importance為
# volume=0.5105      mass=0.19481433   length=0.29464175    shape=0     color=0      rough=0
# 而判斷的方式以volume,mass,length大於或小於某個值為主 皆符合預期
#
# 而第二個Decision tree的feature importance在color的部分有0.02,然而規則和color這個屬性值無關,
# 可能是因為正負樣本不均勻或資料集比較小導致其overfitting的關係
#
# 而每一張圖下面有兩行accuracy代表這顆決策樹(模型)在測試資料集1(正樣本100,負樣本100)和測試資料集2(正樣本100,負樣本30)的表現(以下的其他模型也是)

# %%
train_df_list = read_datasets(RULE_NAME,'train',[(100,100),(100,30)])
test_df_list =  read_datasets(RULE_NAME,'test',[(100,100),(100,30)])
def feature_engineering(df):
    X,y = df.iloc[:, :-1].values,df.iloc[:, -1].values
    return X,y

print('decision tree')
for train_df in train_df_list:
    train_X,train_y = feature_engineering(train_df)
    clf =  DecisionTreeClassifier()
    clf.fit(train_X,train_y)
    print(clf.feature_importances_)
    visualize_tree(clf)
    for test_df in test_df_list:
        test_X,test_y = feature_engineering(test_df)
        evaluate(test_X,test_y,clf)
# Out:
# decision tree
# [0.49254392 0.19567147 0.31178461 0.         0.         0.        ]
# accuracy
# 0.95
# accuracy
# 0.9384615384615385
# [0.28781221 0.56694363 0.12357749 0.         0.02166667 0.        ]
# accuracy
# 0.925
# accuracy
# 0.9153846153846154

# %% [markdown]
# ## Random forest
# 第一個模型為用100筆正樣本和100筆負樣本訓練產生的Random forest
# 第二個模型為用100筆正樣本和30筆負樣本訓練產生的Random forest
# 可以看到feature importance皆不為0,原因是因為random forest挑選特徵時會隨機選擇特徵的subset在從之中選擇最好的特徵
# 但還是可以看出volume mass length的權重比較高
# 本來預估訓練和測試正負樣本不均衡所產生的影響在random forest比較小(因為比較不會overfitting)但從accuracy並無看出

# %%
print('random forest')
for train_df in train_df_list:
    train_X,train_y = feature_engineering(train_df)
    clf = RandomForestClassifier(n_estimators=5000)
    clf.fit(train_X,train_y)
    print(clf.feature_importances_)
    for test_df in test_df_list:
        test_X,test_y = feature_engineering(test_df)
        evaluate(test_X,test_y,clf)
# Out:
# random forest
# [0.414204   0.22850185 0.30407358 0.01579454 0.02340617 0.01401986]
# accuracy
# 0.96
# accuracy
# 0.9461538461538461
# [0.29373658 0.40783419 0.24290804 0.02112537 0.02310112 0.0112947 ]
# accuracy
# 0.925
# accuracy
# 0.9153846153846154

# %% [markdown]
# ## Logistic regression
# 可以看出Logistic regression比起tree based model較不fit data(權重)
# 因為規則並不是依照特徵的線性組合的值決定label的值

# %%
print('logistic regression')
for train_df in train_df_list:
    train_X,train_y = feature_engineering(train_df)
    clf = LogisticRegression()
    clf.fit(train_X,train_y)
    print(clf.coef_)
    for test_df in test_df_list:
        test_X,test_y = feature_engineering(test_df)
        evaluate(test_X,test_y,clf)
# Out:
# logistic regression
# [[-0.02322816  0.03292309  0.0194451   0.10786059  0.0159138  -0.58110158]]
# accuracy
# 0.84
# accuracy
# 0.8538461538461538
# [[-0.02626817  0.06329102 -0.00269809  0.24462668  0.1521802   0.0750519 ]]
# accuracy
# 0.855
# accuracy
# 0.9307692307692308

# %% [markdown]
# # 加入特徵
# 接下來的實驗觀察加入一個和規則產生有高度相關的特徵後
# mass/volume (density) 觀察模型的表現會有多大程度的提升

# %% [markdown]
# # Decision tree
# 可以觀察到decision tree完全catch到rule 所以正確率為100%

# %%
#density
def feature_engineering_with_density(df):
    series = df['mass']/df['volume']
    if 'density' not in df.columns:
        df.insert(2, 'density', series)
    X,y = df.iloc[:, :-1].values,df.iloc[:, -1].values
    return X,y
print('decision tree')
for train_df in train_df_list:
    train_X,train_y = feature_engineering_with_density(train_df)
    clf =  DecisionTreeClassifier()
    clf.fit(train_X,train_y)
    print(clf.feature_importances_)
    visualize_tree(clf,["volume","mass","density","length","shape","color","rough"])
    for test_df in test_df_list:
        test_X,test_y = feature_engineering_with_density(test_df)
        evaluate(test_X,test_y,clf)
# Out:
# decision tree
# [0.         0.         0.70940171 0.29059829 0.         0.
#  0.        ]
# accuracy
# 1.0
# accuracy
# 1.0
# [0.         0.         0.83333333 0.16666667 0.         0.
#  0.        ]
# accuracy
# 1.0
# accuracy
# 1.0

# %% [markdown]
# # Random forest
# 可以觀察到decision tree也幾乎完全catch到rule(density權重非常高) 所以非常接近100%

# %%
print('random forest')
for train_df in train_df_list:
    train_X,train_y = feature_engineering_with_density(train_df)
    clf = RandomForestClassifier(n_estimators=5000)
    clf.fit(train_X,train_y)
    print(clf.feature_importances_)
    for test_df in test_df_list:
        test_X,test_y = feature_engineering_with_density(test_df)
        evaluate(test_X,test_y,clf)
# Out:
# random forest
# [0.20545678 0.09984221 0.43002626 0.24174374 0.0070555  0.0097559
#  0.00611961]
# accuracy
# 1.0
# accuracy
# 1.0
# [0.14950681 0.21077257 0.44093626 0.17534647 0.00988923 0.00926658
#  0.00428207]
# accuracy
# 0.995
# accuracy
# 0.9923076923076923

# %% [markdown]
# # Logistic regression
# 可以觀察到Logistic regression的performance並沒有像樹一樣有明顯提升

# %%
print('logistic regression')
for train_df in train_df_list:
    train_X,train_y = feature_engineering_with_density(train_df)
    clf = LogisticRegression()
    clf.fit(train_X,train_y)
    print(clf.coef_)
    for test_df in test_df_list:
        test_X,test_y = feature_engineering_with_density(test_df)
        evaluate(test_X,test_y,clf)
# Out:
# logistic regression
# [[-0.02825575  0.04246737 -1.93791654  0.02475684  0.11369694  0.02116587
#   -0.56688576]]
# accuracy
# 0.84
# accuracy
# 0.8538461538461538
# [[-2.85035727e-02  6.79973506e-02 -1.16615759e+00  4.10216691e-04
#    2.46841173e-01  1.52871346e-01  7.49838768e-02]]
# accuracy
# 0.86
# accuracy
# 0.9307692307692308
